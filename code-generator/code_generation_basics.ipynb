# %% [markdown]
# # Code Generator
#
# RECOMMENDED: The requirement: use a Frontier model to generate high performance C++ code from Python code.
# OR you could also use an OpenSource model to generate C++ code from python code.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 0px; height: 0px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="0" height="0" : block;" />
#         </td>
#         <td>
#             <h1 style="color:#900;">Important Note</h1>
#             <span style="color:#900;">
#             In this lab, I use high end models GPT 5, Claude 4.5 Sonnet, Gemini 2.5 Pro, Grok 4, which are the slightly higher priced models. The costs are still low, but if you'd prefer to keep costs ultra low, please pick lower cost models like gpt-5-nano.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import subprocess
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)

google_api_key = os.getenv('YOUR_API_KEY')


if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")
# Out:
# Google API Key exists and begins sk

# %%
# Connect to client libraries



gemini_url = "YOUR_API_KEY_BASE_URL"


gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)

# %%
GEMINI_MODEL = "CHOOSE_YOUR_MODEL"

# Want to keep costs ultra-low?, i suggest you use these below models. Uncomment the line below based on which model you choose :

# OPENAI_MODEL = "gpt-5-nano"
# CLAUDE_MODEL = "claude-haiku-4-5"
# GROK_MODEL = "grok-4-fast-non-reasoning"
# GEMINI_MODEL = "gemini-2.5-flash-lite"

# %%
from system_info import retrieve_system_info

system_info = retrieve_system_info()
system_info

# %%
message = f"""
Here is a report of the system information for my computer.
I want to run a C++ compiler to compile a single C++ file called main.cpp and then execute it in the simplest way possible.
Please reply with whether I need to install any C++ compiler to do this. If so, please provide the simplest step by step instructions to do so.

If I'm already set up to compile C++ code, then I'd like to run something like this in Python to compile and execute the code:
```python
compile_command = # something here - to achieve the fastest possible runtime performance
compile_result = subprocess.run(compile_command, check=True, text=True, capture_output=True)
run_command = # something here
run_result = subprocess.run(run_command, check=True, text=True, capture_output=True)
return run_result.stdout
```
Please tell me exactly what I should use for the compile_command and run_command.

System information:
{system_info}
"""

response = gemini.chat.completions.create(model=GEMINI_MODEL, messages=[{"role": "user", "content": message}])
display(Markdown(response.choices[0].message.content))
# Out:
# You are already set up to compile C++ code! Your system information shows that you have **Apple clang version 17.0.0** installed, which is a powerful and modern C++ compiler.
#
# Here's how to compile and execute your `main.cpp` file in the simplest way possible, both directly from the command line and using your Python script.
#
# ## Direct Command Line Compilation and Execution
#
# The simplest way to compile and run your `main.cpp` file from the terminal is:
#
# 1.  **Navigate to your directory:** Open your terminal and use the `cd` command to go to the directory where your `main.cpp` file is located. For example:
#     ```bash
#     cd /path/to/your/cpp/files
#     ```
#
# 2.  **Compile:** Use the `clang++` command. For the fastest possible runtime performance, you should use optimization flags. `-O3` is a good general-purpose optimization level.
#     ```bash
#     clang++ -O3 main.cpp -o main
#     ```
#     *   `clang++`: This is the command to invoke the C++ compiler (Clang).
#     *   `-O3`: This flag tells the compiler to apply aggressive optimizations for speed.
#     *   `main.cpp`: This is your source file.
#     *   `-o main`: This flag specifies the name of the output executable file. If you omit `-o main`, the executable will be named `a.out` by default.
#
# 3.  **Execute:** Run the compiled program.
#     ```bash
#     ./main
#     ```
#     *   `./`: This tells the shell to look for the executable in the current directory.
#
# ## Python Script for Compilation and Execution
#
# Here's how you can use your Python script to achieve the same:
#
# ```python
# import subprocess
# import sys
#
# # Assuming your C++ file is named 'main.cpp' in the same directory
# cpp_file = "main.cpp"
# executable_name = "main"
#
# # Compile command for fastest possible runtime performance
# # -O3: Aggressive optimization for speed
# # -std=c++17: Use C++17 standard (you can adjust this if needed, e.g., c++11, c++14, c++20)
# # -Wall: Enable all common compiler warnings (good practice)
# # -Wextra: Enable even more warnings
# compile_command = [
#     "clang++",
#     "-O3",
#     "-std=c++17",
#     "-Wall",
#     "-Wextra",
#     cpp_file,
#     "-o",
#     executable_name
# ]
#
# try:
#     print(f"Compiling '{cpp_file}'...")
#     compile_result = subprocess.run(
#         compile_command,
#         check=True,         # Raise an exception if the command fails
#         text=True,          # Decode stdout/stderr as text
#         capture_output=True # Capture stdout and stderr
#     )
#     print("Compilation successful.")
#     if compile_result.stdout:
#         print("Compiler stdout:\n", compile_result.stdout)
#     if compile_result.stderr:
#         print("Compiler stderr:\n", compile_result.stderr)
#
#     # Run command
#     run_command = [f"./{executable_name}"]
#
#     print(f"Running '{executable_name}'...")
#     run_result = subprocess.run(
#         run_command,
#         check=True,
#         text=True,
#         capture_output=True
#     )
#     print("Execution successful.")
#     print("Program output:\n", run_result.stdout)
#     return run_result.stdout
#
# except FileNotFoundError:
#     print(f"Error: '{cpp_file}' not found. Please make sure it's in the correct directory.")
#     sys.exit(1)
# except subprocess.CalledProcessError as e:
#     print(f"Error during compilation or execution:")
#     print(f"Command: {' '.join(e.cmd)}")
#     print(f"Return code: {e.returncode}")
#     print(f"Stdout:\n{e.stdout}")
#     print(f"Stderr:\n{e.stderr}")
#     sys.exit(1)
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
#     sys.exit(1)
#
# ```
#
# **Explanation for the Python script:**
#
# *   **`compile_command`**:
#     *   `"clang++"`: Invokes the C++ compiler.
#     *   `"-O3"`: This is the key flag for maximizing runtime performance. It enables aggressive optimizations.
#     *   `"-std=c++17"`: It's good practice to specify a C++ standard. C++17 is a modern and widely supported standard. You can change this to `c++11`, `c++14`, `c++20`, or `c++23` if your code uses features from those standards.
#     *   `"-Wall"` and `"-Wextra"`: These are highly recommended flags to enable a comprehensive set of compiler warnings. They help catch potential bugs and problematic code constructs. While not directly related to runtime performance, they are crucial for writing robust code.
#     *   `cpp_file`: The name of your source file.
#     *   `"-o"`: Specifies the output file name.
#     *   `executable_name`: The name you want for your compiled program.
#
# *   **`run_command`**:
#     *   `[f"./{executable_name}"]`: This creates a list containing the command to execute your compiled program. The `./` is essential to tell the shell to look for the executable in the current directory.
#
# **In summary:**
#
# You do **not** need to install any C++ compiler. Your system comes with `clang++`, which is fully capable of compiling and optimizing your C++ code for the fastest possible runtime performance. The commands provided above will work directly.

# %% [markdown]
# ## If you need to install something
#
# If you would like to, please follow GPTs instructions! Then rerun the analysis afterwards (you might need to Restart the notebook) to confirm you're set.
#
# You should now be equipped with the command to compile the code, and the command to run it!
#
# Enter that in the cell below:

# %%
compile_command = ["clang++", "-std=c++17", "-Ofast", "-mcpu=native", "-flto=thin", "-fvisibility=hidden", "-DNDEBUG", "main.cpp", "-o", "main"]
run_command = ["./main"]

# %% [markdown]
# ## And now, on with the main task

# %%
system_prompt = """
Your task is to convert Python code into high performance C++ code.
Respond only with C++ code. Do not provide any explanation other than occasional comments.
The C++ response needs to produce an identical output in the fastest possible time.
"""

def user_prompt_for(python):
    return f"""
Port this Python code to C++ with the fastest possible implementation that produces identical output in the least time.
The system information is:
{system_info}
Your response will be written to a file called main.cpp and then compiled and executed; the compilation command is:
{compile_command}
Respond only with C++ code.
Python code to port:

```python
{python}
```
"""

# %%
def messages_for(python):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(python)}
    ]

# %%
def write_output(cpp):
    with open("main.cpp", "w", encoding="utf-8") as f:
        f.write(cpp)

# %%
def port(client, model, python):
    reasoning_effort = "high" if 'gpt' in model else None
    response = client.chat.completions.create(model=model, messages=messages_for(python), reasoning_effort=reasoning_effort)
    reply = response.choices[0].message.content
    reply = reply.replace('```cpp','').replace('```','')
    write_output(reply)

# %%
pi = """
import time

def calculate(iterations, param1, param2):
    result = 1.0
    for i in range(1, iterations+1):
        j = i * param1 - param2
        result -= (1/j)
        j = i * param1 + param2
        result += (1/j)
    return result

start_time = time.time()
result = calculate(200_000_000, 4, 1) * 4
end_time = time.time()

print(f"Result: {result:.12f}")
print(f"Execution Time: {(end_time - start_time):.6f} seconds")
"""

# %%
def run_python(code):
    globals = {"__builtins__": __builtins__}
    exec(code, globals)

# %%
run_python(pi)

# %%
port(openai, OPENAI_MODEL, pi)

# %% [markdown]
# # Compiling C++ and executing
#
# This next cell contains the command to compile a C++ file based on the instructions from GPT.

# %%
# Use the commands from GPT 5

def compile_and_run():
    subprocess.run(compile_command, check=True, text=True, capture_output=True)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)

# %%
compile_and_run()

# %%
19.178207/0.082168

# %% [markdown]
# ## OK let's try the other contenders!

# %%
port(anthropic, CLAUDE_MODEL, pi)
compile_and_run()

# %%
port(grok, GROK_MODEL, pi)
compile_and_run()

# %%
port(gemini, GEMINI_MODEL, pi)
compile_and_run()

# %%
print(f"""
In my's experiments, the performance speedups were:

4th place: Claude Sonnet 4.5: {19.178207/0.104241:.0f}X speedup
3rd place: GPT-5: {19.178207/0.082168:.0f}X speedup
2nd place: Grok 4: {19.178207/0.018092:.0f}X speedup
1st place: Gemini 2.5 Pro: {19.178207/0.013314:.0f}X speedup
""")
